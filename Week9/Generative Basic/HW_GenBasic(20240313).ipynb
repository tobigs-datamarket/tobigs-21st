# %% [markdown]
# # Generative Basic Assignment (2024/03/13)
# #### Questions(1,2) are below
# #### Contact -> toa2413@naver.com / 송인혁(투빅스20기)

# %%
import datetime
import os

import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import matplotlib.pylab as plt

import torchvision.datasets as datasets
import torchvision.transforms as transforms

import numpy as np

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
transform = transforms.Compose([transforms.ToTensor()])

train_dataset = datasets.MNIST(
    root="../data", train=True, transform=transform, download=True)

test_dataset = datasets.MNIST(
    root="../data", train=False, transform=transform, download=True)

train_loader = DataLoader(
    train_dataset, batch_size=100, shuffle=True, num_workers=4, pin_memory=False)

test_loader = DataLoader(
    test_dataset, batch_size=100, shuffle=False, num_workers=4)

# %% [markdown]
# ### Q1. Encoder/Decoder Implementation
#     Show me your visualizations(MNIST images) using a VAE model made up of your own 'Encoder2/Decoder2'
#     I can see your visualizations at the last part of this code file (Assignment 1 ; Visualization)
#
# ***You can refer to the examples right under this markdown, please make your own Encoder (Class name; Encoder2/Decoder2)***

# %%
# You can freely choose one of architectures you want that looks promising
class Encoder(nn.Module):    
    def __init__(self, input_dim, hidden_dim, hidden_dim2, latent_dim):
        super(Encoder, self).__init__()
        self.input1 = nn.Linear(input_dim, hidden_dim)
        self.input2 = nn.Linear(hidden_dim, hidden_dim2)
        self.mean = nn.Linear(hidden_dim2, latent_dim)
        self.var = nn.Linear (hidden_dim2, latent_dim)
        
        self.LeakyReLU = nn.LeakyReLU(0.2)        
        self.training = True
        
    def forward(self, x):
        h_ = self.LeakyReLU(self.input1(x))
        h_ = self.LeakyReLU(self.input2(h_))
        mean = self.mean(h_)
        log_var = self.var(h_)                         
        return mean, log_var

# %%
class Encoder2(nn.Module):
    def __init__(self, input_dim, hidden_dims, latent_dim):
        super(Encoder2, self).__init__()
        # Build a sequential model for the encoder
        modules = []
        for h_dim in hidden_dims:
            modules.append(
                nn.Sequential(
                    nn.Linear(input_dim, h_dim),
                    nn.BatchNorm1d(h_dim),
                    nn.ReLU())
            )
            input_dim = h_dim
        
        self.encoder = nn.Sequential(*modules)
        self.fc_mu = nn.Linear(hidden_dims[-1], latent_dim)
        self.fc_var = nn.Linear(hidden_dims[-1], latent_dim)
        
    def forward(self, x):
        x = self.encoder(x)
        mu = self.fc_mu(x)
        log_var = self.fc_var(x)
        return mu, log_var

# %%
class Decoder(nn.Module):
    def __init__(self, latent_dim, hidden_dim, hidden_dim2, output_dim):
        super(Decoder, self).__init__()
        self.hidden1 = nn.Linear(latent_dim, hidden_dim2)
        self.hidden2 = nn.Linear(hidden_dim2, hidden_dim)
        self.output = nn.Linear(hidden_dim, output_dim)        
        self.LeakyReLU = nn.LeakyReLU(0.2)
        
    def forward(self, x):
        h = self.LeakyReLU(self.hidden1(x))
        h = self.LeakyReLU(self.hidden2(h))        
        x_hat = torch.sigmoid(self.output(h))
        return x_hat

# %%
import torch.nn.functional as F

class Decoder2(nn.Module):
    def __init__(self, latent_dim, hidden_dim, hidden_dim2, output_dim):
        super(Decoder2, self).__init__()
        self.fc1 = nn.Linear(latent_dim, hidden_dim2)
        self.fc2 = nn.Linear(hidden_dim2, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, output_dim)
        
    def forward(self, z):
        h = F.relu(self.fc1(z))
        h = F.relu(self.fc2(h))
        reconstruction = torch.sigmoid(self.fc3(h))
        return reconstruction

# %%
class Model(nn.Module):
    def __init__(self, Encoder, Decoder):
        super(Model, self).__init__()
        self.Encoder = Encoder
        self.Decoder = Decoder

    # Think about why you need reparameterization trick (Hint; backpropagation)
    def reparameterization(self, mean, var):
        epsilon = torch.randn_like(var).to(device)                
        z = mean + var*epsilon                          
        return z
                        
    def forward(self, x):
        mean, log_var = self.Encoder(x)
        z = self.reparameterization(mean, torch.exp(0.5 * log_var)) 
        x_hat = self.Decoder(z)        
        return x_hat, mean, log_var

# %%
# Any modifications are allowed depending on your own Encoder2/Decoder2
# -----------------------------------
x_dim  = 784
hidden_dim = 400
hidden_dim2 = 200
latent_dim = 20
epochs = 30
batch_size = 100
# -----------------------------------



# encoder = Encoder(input_dim=x_dim, hidden_dim=hidden_dim, hidden_dim2=hidden_dim2, latent_dim=latent_dim)
encoder = Encoder2(x_dim, (hidden_dim, hidden_dim2), latent_dim)

# decoder = Decoder(latent_dim=latent_dim, hidden_dim = hidden_dim, hidden_dim2=hidden_dim2, output_dim = x_dim)
decoder = Decoder2(latent_dim, hidden_dim, hidden_dim2, x_dim)

model = Model(Encoder=encoder, Decoder=decoder).to(device)

# %% [markdown]
# ### Q2. (Optional Assignment)
#     Refering to Beta-VAE(https://openreview.net/forum?id=Sy2fzU9gl), give any kind of manipulations on pre-made loss function, and visualize your samples.
#     It would be nice to see whether the fidelity of sample data is improved or not! Also guess why.
# ***Warning)  you don't have to take all the contents of this paper! Look carefully at the Equation (4)***

# %%
# (Optional Assignment)
def loss_function(x, x_hat, mean, log_var):
    reproduction_loss = nn.functional.binary_cross_entropy(x_hat, x, reduction='sum')
    # Think about how to calculate KLDivergence in closed form (Hint; assumptions for Gaussian), please refer to the following links
    # https://stats.stackexchange.com/questions/7440/kl-divergence-between-two-univariate-gaussians
    KLD = - 0.5 * torch.sum(1+ log_var - mean.pow(2) - log_var.exp())
    return reproduction_loss, KLD

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# %%
def train(epoch, model, train_loader, optimizer):
    model.train()
    train_loss = 0
    for batch_idx, (x, _) in enumerate(train_loader):
        x = x.view(batch_size, x_dim)
        x = x.to(device)

        optimizer.zero_grad()
        x_hat, mean, log_var = model(x)
        BCE, KLD = loss_function(x, x_hat, mean, log_var)
        loss = BCE + KLD
        
        train_loss += loss.item()  
        loss.backward()
        optimizer.step()
          
        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\t Loss: {:.6f}'.format(
                epoch, batch_idx * len(x), len(train_loader.dataset),
                100. * batch_idx / len(train_loader),
                loss.item() / len(x)))
            
    print("======> Epoch: {} Average loss: {:.4f}".format(
        epoch, train_loss / len(train_loader.dataset)))

# %%
def test(epoch, model, test_loader):
    model.eval()
    test_loss = 0
    with torch.no_grad():
        for batch_idx, (x, _) in enumerate(test_loader):
            x = x.view(batch_size, x_dim)
            x = x.to(device)        
            x_hat, mean, log_var = model(x)
            BCE, KLD = loss_function(x, x_hat, mean, log_var)
            loss = BCE + KLD

            test_loss += loss.item()

            if batch_idx == 0:
                n = min(x.size(0), 8)
                comparison = torch.cat([x[:n], x_hat.view(batch_size, x_dim)[:n]])
                grid = torchvision.utils.make_grid(comparison.cpu())

# %%
# Trackning the process
# If you have difficulty on installing 'tqdm', modifications are allowed. Not necessary 
from tqdm.auto import tqdm

# Training an VAE model, and record losses
for epoch in tqdm(range(0, epochs)):
    train(epoch, model, train_loader, optimizer)
    test(epoch, model, test_loader)
    print("\n")
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Train Epoch: 0 [0/60000 (0%)]	 Loss: 547.736055
# Train Epoch: 0 [10000/60000 (17%)]	 Loss: 169.575137
# Train Epoch: 0 [20000/60000 (33%)]	 Loss: 155.147803
# Train Epoch: 0 [30000/60000 (50%)]	 Loss: 145.573535
# Train Epoch: 0 [40000/60000 (67%)]	 Loss: 145.622051
# Train Epoch: 0 [50000/60000 (83%)]	 Loss: 130.556768
# ======> Epoch: 0 Average loss: 156.2263
#
#
# Train Epoch: 1 [0/60000 (0%)]	 Loss: 128.925322
# Train Epoch: 1 [10000/60000 (17%)]	 Loss: 122.651572
# Train Epoch: 1 [20000/60000 (33%)]	 Loss: 130.523662
# Train Epoch: 1 [30000/60000 (50%)]	 Loss: 121.414756
# Train Epoch: 1 [40000/60000 (67%)]	 Loss: 119.049980
# Train Epoch: 1 [50000/60000 (83%)]	 Loss: 118.140879
# ======> Epoch: 1 Average loss: 122.4474
#
#
# Train Epoch: 2 [0/60000 (0%)]	 Loss: 118.529502
# Train Epoch: 2 [10000/60000 (17%)]	 Loss: 113.545937
# Train Epoch: 2 [20000/60000 (33%)]	 Loss: 114.284395
# Train Epoch: 2 [30000/60000 (50%)]	 Loss: 122.052813
# Train Epoch: 2 [40000/60000 (67%)]	 Loss: 113.974727
# Train Epoch: 2 [50000/60000 (83%)]	 Loss: 112.971582
# ======> Epoch: 2 Average loss: 115.1626
#
#
# Train Epoch: 3 [0/60000 (0%)]	 Loss: 115.413145
# Train Epoch: 3 [10000/60000 (17%)]	 Loss: 118.992461
# Train Epoch: 3 [20000/60000 (33%)]	 Loss: 114.562813
# Train Epoch: 3 [30000/60000 (50%)]	 Loss: 106.543818
# Train Epoch: 3 [40000/60000 (67%)]	 Loss: 114.721924
# Train Epoch: 3 [50000/60000 (83%)]	 Loss: 106.290156
# ======> Epoch: 3 Average loss: 111.7956
#
#
# Train Epoch: 4 [0/60000 (0%)]	 Loss: 114.788096
# Train Epoch: 4 [10000/60000 (17%)]	 Loss: 110.970127
# Train Epoch: 4 [20000/60000 (33%)]	 Loss: 108.485264
# Train Epoch: 4 [30000/60000 (50%)]	 Loss: 112.537891
# Train Epoch: 4 [40000/60000 (67%)]	 Loss: 108.904590
# Train Epoch: 4 [50000/60000 (83%)]	 Loss: 110.333740
# ======> Epoch: 4 Average loss: 109.8477
#
#
# Train Epoch: 5 [0/60000 (0%)]	 Loss: 107.961191
# Train Epoch: 5 [10000/60000 (17%)]	 Loss: 107.518789
# Train Epoch: 5 [20000/60000 (33%)]	 Loss: 111.993437
# Train Epoch: 5 [30000/60000 (50%)]	 Loss: 106.716592
# Train Epoch: 5 [40000/60000 (67%)]	 Loss: 106.426260
# Train Epoch: 5 [50000/60000 (83%)]	 Loss: 108.200928
# ======> Epoch: 5 Average loss: 108.5043
#
#
# Train Epoch: 6 [0/60000 (0%)]	 Loss: 108.591709
# Train Epoch: 6 [10000/60000 (17%)]	 Loss: 106.196738
# Train Epoch: 6 [20000/60000 (33%)]	 Loss: 105.564453
# Train Epoch: 6 [30000/60000 (50%)]	 Loss: 103.658379
# Train Epoch: 6 [40000/60000 (67%)]	 Loss: 107.080391
# Train Epoch: 6 [50000/60000 (83%)]	 Loss: 112.665010
# ======> Epoch: 6 Average loss: 107.4131
#
#
# Train Epoch: 7 [0/60000 (0%)]	 Loss: 105.121279
# Train Epoch: 7 [10000/60000 (17%)]	 Loss: 112.436953
# Train Epoch: 7 [20000/60000 (33%)]	 Loss: 108.851660
# Train Epoch: 7 [30000/60000 (50%)]	 Loss: 106.497441
# Train Epoch: 7 [40000/60000 (67%)]	 Loss: 105.708447
# Train Epoch: 7 [50000/60000 (83%)]	 Loss: 103.734941
# ======> Epoch: 7 Average loss: 106.6987
#
#
# Train Epoch: 8 [0/60000 (0%)]	 Loss: 109.142109
# Train Epoch: 8 [10000/60000 (17%)]	 Loss: 104.339297
# Train Epoch: 8 [20000/60000 (33%)]	 Loss: 107.870898
# Train Epoch: 8 [30000/60000 (50%)]	 Loss: 101.487090
# Train Epoch: 8 [40000/60000 (67%)]	 Loss: 108.287354
# Train Epoch: 8 [50000/60000 (83%)]	 Loss: 102.386943
# ======> Epoch: 8 Average loss: 106.0439
#
#
# Train Epoch: 9 [0/60000 (0%)]	 Loss: 104.851191
# Train Epoch: 9 [10000/60000 (17%)]	 Loss: 110.413477
# Train Epoch: 9 [20000/60000 (33%)]	 Loss: 103.815098
# Train Epoch: 9 [30000/60000 (50%)]	 Loss: 105.867793
# Train Epoch: 9 [40000/60000 (67%)]	 Loss: 106.778887
# Train Epoch: 9 [50000/60000 (83%)]	 Loss: 104.128828
# ======> Epoch: 9 Average loss: 105.4061
#
#
# Train Epoch: 10 [0/60000 (0%)]	 Loss: 99.250996
# Train Epoch: 10 [10000/60000 (17%)]	 Loss: 102.934385
# Train Epoch: 10 [20000/60000 (33%)]	 Loss: 104.864668
# Train Epoch: 10 [30000/60000 (50%)]	 Loss: 109.213594
# Train Epoch: 10 [40000/60000 (67%)]	 Loss: 103.328047
# Train Epoch: 10 [50000/60000 (83%)]	 Loss: 104.670098
# ======> Epoch: 10 Average loss: 104.9161
#
#
# Train Epoch: 11 [0/60000 (0%)]	 Loss: 101.834668
# Train Epoch: 11 [10000/60000 (17%)]	 Loss: 102.923613
# Train Epoch: 11 [20000/60000 (33%)]	 Loss: 107.400771
# Train Epoch: 11 [30000/60000 (50%)]	 Loss: 104.631768
# Train Epoch: 11 [40000/60000 (67%)]	 Loss: 100.073232
# Train Epoch: 11 [50000/60000 (83%)]	 Loss: 100.768438
# ======> Epoch: 11 Average loss: 104.6231
#
#
# Train Epoch: 12 [0/60000 (0%)]	 Loss: 104.230840
# Train Epoch: 12 [10000/60000 (17%)]	 Loss: 103.156260
# Train Epoch: 12 [20000/60000 (33%)]	 Loss: 104.934600
# Train Epoch: 12 [30000/60000 (50%)]	 Loss: 106.487695
# Train Epoch: 12 [40000/60000 (67%)]	 Loss: 102.625332
# Train Epoch: 12 [50000/60000 (83%)]	 Loss: 105.705879
# ======> Epoch: 12 Average loss: 104.3068
#
#
# Train Epoch: 13 [0/60000 (0%)]	 Loss: 102.834570
# Train Epoch: 13 [10000/60000 (17%)]	 Loss: 97.644141
# Train Epoch: 13 [20000/60000 (33%)]	 Loss: 98.444766
# Train Epoch: 13 [30000/60000 (50%)]	 Loss: 109.984844
# Train Epoch: 13 [40000/60000 (67%)]	 Loss: 103.810049
# Train Epoch: 13 [50000/60000 (83%)]	 Loss: 106.224795
# ======> Epoch: 13 Average loss: 103.9024
#
#
# Train Epoch: 14 [0/60000 (0%)]	 Loss: 104.163320
# Train Epoch: 14 [10000/60000 (17%)]	 Loss: 102.550137
# Train Epoch: 14 [20000/60000 (33%)]	 Loss: 101.724238
# Train Epoch: 14 [30000/60000 (50%)]	 Loss: 100.875566
# Train Epoch: 14 [40000/60000 (67%)]	 Loss: 101.025117
# Train Epoch: 14 [50000/60000 (83%)]	 Loss: 98.043174
# ======> Epoch: 14 Average loss: 103.7088
#
#
# Train Epoch: 15 [0/60000 (0%)]	 Loss: 105.367588
# Train Epoch: 15 [10000/60000 (17%)]	 Loss: 107.139961
# Train Epoch: 15 [20000/60000 (33%)]	 Loss: 102.914219
# Train Epoch: 15 [30000/60000 (50%)]	 Loss: 103.253574
# Train Epoch: 15 [40000/60000 (67%)]	 Loss: 101.025781
# Train Epoch: 15 [50000/60000 (83%)]	 Loss: 104.078906
# ======> Epoch: 15 Average loss: 103.3833
#
#
# Train Epoch: 16 [0/60000 (0%)]	 Loss: 103.068105
# Train Epoch: 16 [10000/60000 (17%)]	 Loss: 100.795801
# Train Epoch: 16 [20000/60000 (33%)]	 Loss: 95.752285
# Train Epoch: 16 [30000/60000 (50%)]	 Loss: 100.953848
# Train Epoch: 16 [40000/60000 (67%)]	 Loss: 109.692725
# Train Epoch: 16 [50000/60000 (83%)]	 Loss: 95.879717
# ======> Epoch: 16 Average loss: 103.0496
#
#
# Train Epoch: 17 [0/60000 (0%)]	 Loss: 102.997520
# Train Epoch: 17 [10000/60000 (17%)]	 Loss: 101.831436
# Train Epoch: 17 [20000/60000 (33%)]	 Loss: 102.716484
# Train Epoch: 17 [30000/60000 (50%)]	 Loss: 101.251230
# Train Epoch: 17 [40000/60000 (67%)]	 Loss: 109.319932
# Train Epoch: 17 [50000/60000 (83%)]	 Loss: 101.470449
# ======> Epoch: 17 Average loss: 102.8433
#
#
# Train Epoch: 18 [0/60000 (0%)]	 Loss: 106.519473
# Train Epoch: 18 [10000/60000 (17%)]	 Loss: 102.425918
# Train Epoch: 18 [20000/60000 (33%)]	 Loss: 101.233223
# Train Epoch: 18 [30000/60000 (50%)]	 Loss: 106.141465
# Train Epoch: 18 [40000/60000 (67%)]	 Loss: 103.106533
# Train Epoch: 18 [50000/60000 (83%)]	 Loss: 100.709229
# ======> Epoch: 18 Average loss: 102.6426
#
#
# Train Epoch: 19 [0/60000 (0%)]	 Loss: 105.009795
# Train Epoch: 19 [10000/60000 (17%)]	 Loss: 102.400352
# Train Epoch: 19 [20000/60000 (33%)]	 Loss: 104.385176
# Train Epoch: 19 [30000/60000 (50%)]	 Loss: 106.596797
# Train Epoch: 19 [40000/60000 (67%)]	 Loss: 98.490205
# Train Epoch: 19 [50000/60000 (83%)]	 Loss: 101.666553
# ======> Epoch: 19 Average loss: 102.5832
#
#
# Train Epoch: 20 [0/60000 (0%)]	 Loss: 105.495654
# Train Epoch: 20 [10000/60000 (17%)]	 Loss: 105.302383
# Train Epoch: 20 [20000/60000 (33%)]	 Loss: 104.170400
# Train Epoch: 20 [30000/60000 (50%)]	 Loss: 100.794326
# Train Epoch: 20 [40000/60000 (67%)]	 Loss: 102.728730
# Train Epoch: 20 [50000/60000 (83%)]	 Loss: 98.707090
# ======> Epoch: 20 Average loss: 102.4345
#
#
# Train Epoch: 21 [0/60000 (0%)]	 Loss: 106.256250
# Train Epoch: 21 [10000/60000 (17%)]	 Loss: 103.089902
# Train Epoch: 21 [20000/60000 (33%)]	 Loss: 101.035645
# Train Epoch: 21 [30000/60000 (50%)]	 Loss: 104.702383
# Train Epoch: 21 [40000/60000 (67%)]	 Loss: 99.816523
# Train Epoch: 21 [50000/60000 (83%)]	 Loss: 102.187187
# ======> Epoch: 21 Average loss: 102.1737
#
#
# Train Epoch: 22 [0/60000 (0%)]	 Loss: 100.232617
# Train Epoch: 22 [10000/60000 (17%)]	 Loss: 98.542588
# Train Epoch: 22 [20000/60000 (33%)]	 Loss: 99.644609
# Train Epoch: 22 [30000/60000 (50%)]	 Loss: 100.749004
# Train Epoch: 22 [40000/60000 (67%)]	 Loss: 102.896484
# Train Epoch: 22 [50000/60000 (83%)]	 Loss: 99.607637
# ======> Epoch: 22 Average loss: 102.0140
#
#
# Train Epoch: 23 [0/60000 (0%)]	 Loss: 100.464414
# Train Epoch: 23 [10000/60000 (17%)]	 Loss: 103.040820
# Train Epoch: 23 [20000/60000 (33%)]	 Loss: 100.479004
# Train Epoch: 23 [30000/60000 (50%)]	 Loss: 104.859814
# Train Epoch: 23 [40000/60000 (67%)]	 Loss: 103.343301
# Train Epoch: 23 [50000/60000 (83%)]	 Loss: 101.235059
# ======> Epoch: 23 Average loss: 101.7964
#
#
# Train Epoch: 24 [0/60000 (0%)]	 Loss: 99.049395
# Train Epoch: 24 [10000/60000 (17%)]	 Loss: 103.275850
# Train Epoch: 24 [20000/60000 (33%)]	 Loss: 100.905244
# Train Epoch: 24 [30000/60000 (50%)]	 Loss: 101.619961
# Train Epoch: 24 [40000/60000 (67%)]	 Loss: 104.508555
# Train Epoch: 24 [50000/60000 (83%)]	 Loss: 101.712559
# ======> Epoch: 24 Average loss: 101.7185
#
#
# Train Epoch: 25 [0/60000 (0%)]	 Loss: 103.371973
# Train Epoch: 25 [10000/60000 (17%)]	 Loss: 99.140742
# Train Epoch: 25 [20000/60000 (33%)]	 Loss: 105.247969
# Train Epoch: 25 [30000/60000 (50%)]	 Loss: 99.259062
# Train Epoch: 25 [40000/60000 (67%)]	 Loss: 104.499434
# Train Epoch: 25 [50000/60000 (83%)]	 Loss: 102.156367
# ======> Epoch: 25 Average loss: 101.6258
#
#
# Train Epoch: 26 [0/60000 (0%)]	 Loss: 102.162959
# Train Epoch: 26 [10000/60000 (17%)]	 Loss: 103.332363
# Train Epoch: 26 [20000/60000 (33%)]	 Loss: 102.483926
# Train Epoch: 26 [30000/60000 (50%)]	 Loss: 101.095244
# Train Epoch: 26 [40000/60000 (67%)]	 Loss: 100.799688
# Train Epoch: 26 [50000/60000 (83%)]	 Loss: 103.051758
# ======> Epoch: 26 Average loss: 101.5628
#
#
# Train Epoch: 27 [0/60000 (0%)]	 Loss: 101.414502
# Train Epoch: 27 [10000/60000 (17%)]	 Loss: 97.890234
# Train Epoch: 27 [20000/60000 (33%)]	 Loss: 101.027637
# Train Epoch: 27 [30000/60000 (50%)]	 Loss: 102.567246
# Train Epoch: 27 [40000/60000 (67%)]	 Loss: 105.774570
# Train Epoch: 27 [50000/60000 (83%)]	 Loss: 100.006406
# ======> Epoch: 27 Average loss: 101.3409
#
#
# Train Epoch: 28 [0/60000 (0%)]	 Loss: 101.958135
# Train Epoch: 28 [10000/60000 (17%)]	 Loss: 96.664199
# Train Epoch: 28 [20000/60000 (33%)]	 Loss: 100.839336
# Train Epoch: 28 [30000/60000 (50%)]	 Loss: 100.436797
# Train Epoch: 28 [40000/60000 (67%)]	 Loss: 98.609531
# Train Epoch: 28 [50000/60000 (83%)]	 Loss: 101.090752
# ======> Epoch: 28 Average loss: 101.1714
#
#
# Train Epoch: 29 [0/60000 (0%)]	 Loss: 102.882031
# Train Epoch: 29 [10000/60000 (17%)]	 Loss: 102.986436
# Train Epoch: 29 [20000/60000 (33%)]	 Loss: 100.679043
# Train Epoch: 29 [30000/60000 (50%)]	 Loss: 102.019531
# Train Epoch: 29 [40000/60000 (67%)]	 Loss: 103.622920
# Train Epoch: 29 [50000/60000 (83%)]	 Loss: 103.045254
# ======> Epoch: 29 Average loss: 101.1667

# %%
# After training decoder, begin visualize what comes after decoder given input z
def visualize(decoder,z):
    x_sample = decoder(z).view(20,28,28).cpu().detach().numpy()
    fig, axes = plt.subplots(nrows=1, ncols=20, figsize=(20, 8))
    for i, ax in enumerate(axes.flat):
        ax.imshow(x_sample[i], cmap='gray')
        ax.axis('off')
    plt.tight_layout()
    plt.show()

z_sample = torch.randn(20,20).to('cuda')

# (Assignment 1 ; Visualization)
visualize(decoder,z_sample)

# %%
# Set seed numbers to take reproducibility
seed = 3
torch.manual_seed(seed)
# torch.cuda.manual_seed(seed)
np.random.seed(seed)

# Random z
z = torch.randn(20).to('cuda')
# Make copies
z = z.repeat(20,1).to('cuda')

# Interpolation in latent space z 
for i in range(20):
    z[i, 0] += i * 0.5 - (20 - 1) * 0.5 / 2

# (Assignment 1 ; Visualization)
visualize(decoder,z)

# %% [markdown]
# ## Answer(Q2; Optional) : Please write any codes or statements below this space
